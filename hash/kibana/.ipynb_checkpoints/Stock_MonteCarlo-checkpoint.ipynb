# %% [markdown]
# ## Groupe 10 Kibana project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Votre code Java ne compilant pas sur mon mac, j'ai fait les manipulations dont j'avais besoin en python

# %%
google = pd.read_csv("GOOG.csv") 
amazon = pd.read_csv("AMZN.csv") 
apple = pd.read_csv("AAPL.csv") 
facebook = pd.read_csv("FB.csv")

# %%
google.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-04-22  532.936829  539.598511  530.294067  537.888245  537.888245
# 1  2015-04-23  539.518738  549.451477  538.750854  545.502319  545.502319
# 2  2015-04-24  564.550049  569.576233  555.724243  563.512878  563.512878
# 3  2015-04-27  563.390015  565.950012  553.200012  555.369995  555.369995
# 4  2015-04-28  554.640015  556.020020  550.366028  553.679993  553.679993
#
#     Volume
# 0  1593500
# 1  4184800
# 2  4932500
# 3  2398000
# 4  1491000

# %%
n = len(google['Open'])
X = [ i for i in range(n)]
google['id_google'] = X
google.set_index('id_google')
google.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-04-22  532.936829  539.598511  530.294067  537.888245  537.888245
# 1  2015-04-23  539.518738  549.451477  538.750854  545.502319  545.502319
# 2  2015-04-24  564.550049  569.576233  555.724243  563.512878  563.512878
# 3  2015-04-27  563.390015  565.950012  553.200012  555.369995  555.369995
# 4  2015-04-28  554.640015  556.020020  550.366028  553.679993  553.679993
#
#     Volume  id_google
# 0  1593500          0
# 1  4184800          1
# 2  4932500          2
# 3  2398000          3
# 4  1491000          4

# %%
n = len(google['Open'])
print(n)
# Out:
# 1258

# %%
n = len(facebook['Open'])
print(n)
# Out:
# 1258

# %%
n = len(amazon['Open'])
print(n)
# Out:
# 1258

# %%
n = len(apple['Open'])
print(n)
# Out:
# 1258

# %%
apple['id_apple'] = X
apple.set_index('id_apple')

amazon['id_amazon'] = X
amazon.set_index('id_amazon')

facebook['id_facebook'] = X
facebook.set_index('id_facebook')
# Out:
#                    Date        Open        High         Low       Close  \
# id_facebook
# 0            2015-04-22   84.320000   84.739998   83.650002   84.629997
# 1            2015-04-23   84.099998   85.589996   82.410004   82.410004
# 2            2015-04-24   82.769997   82.940002   81.480003   81.529999
# 3            2015-04-27   81.870003   82.930000   81.629997   81.910004
# 4            2015-04-28   81.830002   81.900002   80.230003   80.680000
# 5            2015-04-29   80.010002   81.389999   79.519997   80.470001
# 6            2015-04-30   80.010002   80.959999   78.320000   78.769997
# 7            2015-05-01   79.239998   79.760002   78.110001   78.989998
# 8            2015-05-04   79.330002   79.690002   78.629997   78.809998
# 9            2015-05-05   78.550003   78.800003   77.220001   77.559998
# 10           2015-05-06   77.970001   78.809998   77.050003   78.099998
# 11           2015-05-07   78.000000   78.940002   77.559998   78.430000
# 12           2015-05-08   79.099998   79.230003   78.029999   78.510002
# 13           2015-05-11   78.480003   79.029999   77.930000   78.010002
# 14           2015-05-12   77.870003   77.889999   76.790001   77.459999
# 15           2015-05-13   77.720001   78.529999   77.650002   78.440002
# 16           2015-05-14   78.940002   81.849998   78.669998   81.370003
# 17           2015-05-15   81.410004   81.519997   80.180000   80.419998
# 18           2015-05-18   80.330002   81.379997   80.230003   80.879997
# 19           2015-05-19   81.250000   81.690002   80.550003   80.629997
# 20           2015-05-20   80.470001   81.099998   79.459999   80.550003
# 21           2015-05-21   80.190002   80.919998   80.080002   80.480003
# 22           2015-05-22   80.349998   81.309998   80.250000   80.540001
# 1230         170.240005  20373900
# 1231         154.470001  43266300
# 1232         170.279999  35028600
# 1233         146.009995  39120400
# 1234         149.419998  34255600
# 1235         146.960007  37553100
# 1236         153.130005  39862300
# 1237         149.729996  32568400
# 1238         148.100006  29830800
# 1239         160.979996  30440400
# 1240         156.210007  35184300
# 1241         163.339996  26556800
# 1242         156.789993  24879900
# 1243         165.949997  22515200
# 1244         166.800003  23676300
# 1245         159.600006  19507600
# 1246         158.190002  20886300
# 1247         154.179993  25983300
# 1248         165.550003  28453600
# 1249         168.830002  31411900
# 1250         174.279999  21664200
# 1251         175.190002  23534300
# 1252         174.789993  19355400
# 1253         178.169998  21011800
# 1254         176.970001  17423000
# 1255         176.250000  23593200
# 1256         179.240005  20974800
# 1257         178.240005  16110700
#
# [1258 rows x 7 columns]

# %%
google['variation'] = ( (google['High'] - google['Low']) /  google['High'] ) * 100
amazon['variation'] = ( ( amazon['High'] - amazon['Low'] ) / amazon['High'] ) * 100
apple['variation'] = ( ( apple['High'] - apple['Low'] ) / apple['High'] ) * 100
facebook['variation'] = ( ( facebook['High'] - facebook['Low'] ) / facebook['High'] ) * 100

google.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-04-22  532.936829  539.598511  530.294067  537.888245  537.888245
# 1  2015-04-23  539.518738  549.451477  538.750854  545.502319  545.502319
# 2  2015-04-24  564.550049  569.576233  555.724243  563.512878  563.512878
# 3  2015-04-27  563.390015  565.950012  553.200012  555.369995  555.369995
# 4  2015-04-28  554.640015  556.020020  550.366028  553.679993  553.679993
#
#     Volume  id_google  variation
# 0  1593500          0   1.724327
# 1  4184800          1   1.947510
# 2  4932500          2   2.431982
# 3  2398000          3   2.252849
# 4  1491000          4   1.016868

# %%
portfolio = pd.read_csv("portfolio.csv") 
portfolio['date'] = google['Date']

portfolio['id_google'] = google['id_google']
portfolio['id_facebook'] = facebook['id_facebook']
portfolio['id_amazon'] = amazon['id_amazon']
portfolio['id_apple'] = apple['id_apple']

portfolio.head()
# Out:
#          date  id_google  id_facebook  id_amazon  id_apple mean
# 0  2015-04-22          0            0          0         0  NaN
# 1  2015-04-23          1            1          1         1  NaN
# 2  2015-04-24          2            2          2         2  NaN
# 3  2015-04-27          3            3          3         3  NaN
# 4  2015-04-28          4            4          4         4  NaN

# %%
portfolio['mean'] = google['variation'] + facebook['variation'] + amazon['variation'] + apple['variation']
# Out:
# /Users/pel_btc_coding/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ----------------------------------------------------------------------
# KeyboardInterrupt                    Traceback (most recent call last)
# <ipython-input-108-71d9df43d0af> in <module>()
#       1
#       2 for i in range(len(portfolio['date']) - 1):
# ----> 3     portfolio['mean'][i] = google['Open'][i]
#       4
#       5 portfolio.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1036
#    1037         # do the setitem
# -> 1038         cacher_needs_updating = self._check_is_chained_assignment_possible()
#    1039         setitem(key, value)
#    1040         if cacher_needs_updating:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _check_is_chained_assignment_possible(self)
#    3197             if ref is not None and ref._is_mixed_type:
#    3198                 self._check_setitem_copy(stacklevel=4, t='referant',
# -> 3199                                          force=True)
#    3200             return True
#    3201         elif self._is_copy:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    3243             # the copy weakref
#    3244             try:
# -> 3245                 gc.collect(2)
#    3246                 if not gc.get_referents(self._is_copy()):
#    3247                     self._is_copy = None
#
# KeyboardInterrupt:
